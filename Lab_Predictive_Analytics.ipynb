# %% [markdown]
# ###  **<font color=#2F4F4F>Simple Linear Regression</font>**

# %% [markdown]
# #### <font color=#778899>**Problem description**</font>

# %% [markdown]
#  <font color=#2F4F4F> <p align="justify"> Imagine you want to determine the salary you could potentially earn after a specific number of years of experience. You possess data on individuals' years of experience paired with their respective salaries. How can you utilize this data to estimate your own salary after a certain number of years of experience? </p></font>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/krishnaik06/simple-Linear-Regression/master/Salary_Data.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %% [markdown]
# ###  **<font color=#2F4F4F>Multiple Linear Regression</font>**

# %% [markdown]
# - Multiple Linear Regression is a statistical technique that models the relationship between a dependent variable and **two or more independent variables** using a linear equation.

# %% [markdown]
# #### <font color=#778899>**Problem description**</font>

# %% [markdown]
# <font color=#2F4F4F> <p align="justify"> Given a dataset with features including **engine size** and the **number of cylinders** in cars, the problem is to develop a predictive model that can accurately **estimate CO2 emissions** based on these factors.
#  </p></font>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/kvinlazy/Dataset/master/FuelConsumptionCo2.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...
